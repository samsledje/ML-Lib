# %%
# %load_ext autoreload
# %autoreload 2

# %%
from roc import load_data, plot_roc, train_test_split
from Classifiers import LogisticRegressionClassifier
from sklearn.linear_model import LogisticRegression

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
features, targets = load_data()

# %%
train_x, train_y, test_x, test_y = train_test_split(features, targets, 2/3)

# %%
logreg = LogisticRegressionClassifier()
logreg.fit(train_x, train_y)
probabilities = logreg.predict_proba(test_x)
plot_roc("ROC Curve for Wisconsin Breast Cancer Dataset", test_y, probabilities)

# %%
pred = logreg.pred(test

# %%
sk = LogisticRegression()
sk.fit(train_x, train_y)
sk_proba = sk.predict_proba(test_x)
plot_roc("ROC Curve using SKLearn", test_y, pd.DataFrame(sk_proba)[1].values)
